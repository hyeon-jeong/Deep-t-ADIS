# %%
import os
def createfolder(folder):
    try:
        if not os.path.exists(folder):
            os.makedirs(folder)
    except OSError:
        print('Error: creating directory' + folder)

# %%
import PIL
from PIL import Image

def load_image_file(file, mode='RGB'):
    im = PIL.Image.open(file)
    if mode:
        im = im.convert(mode)
    return np.array(im)

# %%
import cv2
import numpy as np
import face_recognition
from skimage import io

videoname = 'sample4'
path = videoname+'_frame'
#'C:\Users\user\Documents\cyber17\Face_Detection\'
video = cv2.VideoCapture(videoname+'.mp4')
count = 0
faces = []

videoframe = video.get(cv2.CAP_PROP_POS_FRAMES)
videocount = video.get(cv2.CAP_PROP_FRAME_COUNT)

createfolder(path)

while video.isOpened():
    #ret 은 프레임이 존재하지 않을때 T/F 반환
    #frame 은 프레임 반환
    if(videoframe == videocount):
        video.open(videoname+'.mp4')
    
    ret, frame = video.read()
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    if ret == False:
        print("Frame doesn't Exist")
        break
    
    try:
        #face_location 은 얼굴 위치(행렬에서)
        face_location = face_recognition.face_locations(frame) #cnn 모델 사용
        top, right, bottom, left = face_location[0]
        print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

        #face_location 찾아서 파일로 저장
        face_image = Image.fromarray(frame[top:bottom, left:right])
        #Image.fromarray(face_image).show()
        face_image.save(videoname+'_frame/frame %d.jpg' %count)
        #print('Saved frame%d.jpg' %count)
        count += 1
        
    except :
        pass

print(faces)
video.release()
cv2.destroyAllWindows()
# Out:
# A face is located at pixel location Top: 136, Left: 344, Bottom: 226, Right: 434
# A face is located at pixel location Top: 126, Left: 354, Bottom: 216, Right: 444
# A face is located at pixel location Top: 126, Left: 364, Bottom: 216, Right: 454
# A face is located at pixel location Top: 126, Left: 364, Bottom: 216, Right: 454
# A face is located at pixel location Top: 126, Left: 374, Bottom: 216, Right: 464
# A face is located at pixel location Top: 126, Left: 374, Bottom: 216, Right: 464
# A face is located at pixel location Top: 126, Left: 384, Bottom: 216, Right: 474
# A face is located at pixel location Top: 126, Left: 384, Bottom: 216, Right: 474
# A face is located at pixel location Top: 126, Left: 394, Bottom: 216, Right: 484
# A face is located at pixel location Top: 126, Left: 394, Bottom: 216, Right: 484
# A face is located at pixel location Top: 126, Left: 404, Bottom: 216, Right: 494
# A face is located at pixel location Top: 126, Left: 404, Bottom: 216, Right: 494
# A face is located at pixel location Top: 130, Left: 419, Bottom: 204, Right: 494
# A face is located at pixel location Top: 116, Left: 414, Bottom: 206, Right: 504
# A face is located at pixel location Top: 126, Left: 414, Bottom: 216, Right: 504
# A face is located at pixel location Top: 130, Left: 428, Bottom: 204, Right: 502
# A face is located at pixel location Top: 130, Left: 428, Bottom: 204, Right: 502
# A face is located at pixel location Top: 126, Left: 424, Bottom: 216, Right: 514
# A face is located at pixel location Top: 126, Left: 424, Bottom: 216, Right: 514
# A face is located at pixel location Top: 115, Left: 280, Bottom: 177, Right: 342
# A face is located at pixel location Top: 105, Left: 287, Bottom: 179, Right: 361
# A face is located at pixel location Top: 105, Left: 303, Bottom: 179, Right: 378
# A face is located at pixel location Top: 113, Left: 320, Bottom: 188, Right: 395
# A face is located at pixel location Top: 113, Left: 328, Bottom: 188, Right: 403
# A face is located at pixel location Top: 113, Left: 345, Bottom: 188, Right: 419
# A face is located at pixel location Top: 113, Left: 361, Bottom: 188, Right: 436
# A face is located at pixel location Top: 116, Left: 364, Bottom: 206, Right: 454
# A face is located at pixel location Top: 130, Left: 386, Bottom: 204, Right: 461
# A face is located at pixel location Top: 126, Left: 394, Bottom: 216, Right: 484
# A face is located at pixel location Top: 140, Left: 366, Bottom: 247, Right: 474
# A face is located at pixel location Top: 140, Left: 354, Bottom: 247, Right: 462
# A face is located at pixel location Top: 146, Left: 354, Bottom: 236, Right: 444
# A face is located at pixel location Top: 136, Left: 344, Bottom: 226, Right: 434
# A face is located at pixel location Top: 136, Left: 335, Bottom: 226, Right: 424
# A face is located at pixel location Top: 126, Left: 325, Bottom: 216, Right: 414
# A face is located at pixel location Top: 126, Left: 315, Bottom: 216, Right: 404
# A face is located at pixel location Top: 116, Left: 305, Bottom: 206, Right: 394
# A face is located at pixel location Top: 116, Left: 305, Bottom: 206, Right: 394
# A face is located at pixel location Top: 104, Left: 282, Bottom: 211, Right: 390
# A face is located at pixel location Top: 104, Left: 270, Bottom: 211, Right: 378
# A face is located at pixel location Top: 104, Left: 259, Bottom: 211, Right: 366
# A face is located at pixel location Top: 106, Left: 255, Bottom: 196, Right: 344
# A face is located at pixel location Top: 106, Left: 245, Bottom: 196, Right: 335
# A face is located at pixel location Top: 106, Left: 235, Bottom: 196, Right: 325
# A face is located at pixel location Top: 104, Left: 223, Bottom: 211, Right: 330
# A face is located at pixel location Top: 104, Left: 223, Bottom: 211, Right: 330
# A face is located at pixel location Top: 92, Left: 211, Bottom: 199, Right: 318
# A face is located at pixel location Top: 92, Left: 211, Bottom: 199, Right: 318
# A face is located at pixel location Top: 106, Left: 215, Bottom: 196, Right: 305
# A face is located at pixel location Top: 106, Left: 215, Bottom: 196, Right: 305
# A face is located at pixel location Top: 92, Left: 211, Bottom: 199, Right: 318
# A face is located at pixel location Top: 92, Left: 211, Bottom: 199, Right: 318
# A face is located at pixel location Top: 106, Left: 225, Bottom: 196, Right: 315
# A face is located at pixel location Top: 92, Left: 223, Bottom: 199, Right: 330
# A face is located at pixel location Top: 92, Left: 223, Bottom: 199, Right: 330
# A face is located at pixel location Top: 96, Left: 235, Bottom: 186, Right: 325
# A face is located at pixel location Top: 96, Left: 235, Bottom: 186, Right: 325
# A face is located at pixel location Top: 96, Left: 235, Bottom: 186, Right: 325
# A face is located at pixel location Top: 106, Left: 235, Bottom: 196, Right: 325
# A face is located at pixel location Top: 106, Left: 235, Bottom: 196, Right: 325
# A face is located at pixel location Top: 106, Left: 235, Bottom: 196, Right: 325
# A face is located at pixel location Top: 106, Left: 235, Bottom: 196, Right: 325
# A face is located at pixel location Top: 92, Left: 223, Bottom: 199, Right: 330
# A face is located at pixel location Top: 92, Left: 223, Bottom: 199, Right: 330
# A face is located at pixel location Top: 92, Left: 223, Bottom: 199, Right: 330
# A face is located at pixel location Top: 92, Left: 223, Bottom: 199, Right: 330
# A face is located at pixel location Top: 92, Left: 223, Bottom: 199, Right: 330
# A face is located at pixel location Top: 104, Left: 223, Bottom: 211, Right: 330
# A face is located at pixel location Top: 104, Left: 223, Bottom: 211, Right: 330
# A face is located at pixel location Top: 104, Left: 223, Bottom: 211, Right: 330
# A face is located at pixel location Top: 106, Left: 235, Bottom: 196, Right: 325
# A face is located at pixel location Top: 106, Left: 235, Bottom: 196, Right: 325
# A face is located at pixel location Top: 106, Left: 235, Bottom: 196, Right: 325
# A face is located at pixel location Top: 106, Left: 235, Bottom: 196, Right: 325
# A face is located at pixel location Top: 106, Left: 245, Bottom: 196, Right: 335
# A face is located at pixel location Top: 106, Left: 245, Bottom: 196, Right: 335
# A face is located at pixel location Top: 106, Left: 255, Bottom: 196, Right: 344
# A face is located at pixel location Top: 92, Left: 247, Bottom: 199, Right: 354
# A face is located at pixel location Top: 92, Left: 247, Bottom: 199, Right: 354
# A face is located at pixel location Top: 92, Left: 247, Bottom: 199, Right: 354
# A face is located at pixel location Top: 92, Left: 247, Bottom: 199, Right: 354
# A face is located at pixel location Top: 92, Left: 247, Bottom: 199, Right: 354
# A face is located at pixel location Top: 92, Left: 247, Bottom: 199, Right: 354
# A face is located at pixel location Top: 92, Left: 247, Bottom: 199, Right: 354
# A face is located at pixel location Top: 92, Left: 247, Bottom: 199, Right: 354
# A face is located at pixel location Top: 92, Left: 247, Bottom: 199, Right: 354
# A face is located at pixel location Top: 92, Left: 247, Bottom: 199, Right: 354
# A face is located at pixel location Top: 92, Left: 247, Bottom: 199, Right: 354
# A face is located at pixel location Top: 92, Left: 247, Bottom: 199, Right: 354
# A face is located at pixel location Top: 92, Left: 247, Bottom: 199, Right: 354
# A face is located at pixel location Top: 92, Left: 247, Bottom: 199, Right: 354
# A face is located at pixel location Top: 106, Left: 255, Bottom: 196, Right: 344
# A face is located at pixel location Top: 106, Left: 255, Bottom: 196, Right: 344
# A face is located at pixel location Top: 116, Left: 255, Bottom: 206, Right: 344
# A face is located at pixel location Top: 116, Left: 255, Bottom: 206, Right: 344
# A face is located at pixel location Top: 116, Left: 245, Bottom: 206, Right: 335
# A face is located at pixel location Top: 116, Left: 245, Bottom: 206, Right: 335
# A face is located at pixel location Top: 104, Left: 235, Bottom: 211, Right: 342
# A face is located at pixel location Top: 104, Left: 235, Bottom: 211, Right: 342
# A face is located at pixel location Top: 116, Left: 255, Bottom: 206, Right: 344
# A face is located at pixel location Top: 116, Left: 255, Bottom: 206, Right: 344
# A face is located at pixel location Top: 104, Left: 247, Bottom: 211, Right: 354
# A face is located at pixel location Top: 104, Left: 247, Bottom: 211, Right: 354
# A face is located at pixel location Top: 104, Left: 247, Bottom: 211, Right: 354
# A face is located at pixel location Top: 116, Left: 265, Bottom: 206, Right: 354
# A face is located at pixel location Top: 104, Left: 259, Bottom: 211, Right: 366
# A face is located at pixel location Top: 104, Left: 259, Bottom: 211, Right: 366
# A face is located at pixel location Top: 104, Left: 259, Bottom: 211, Right: 366
# A face is located at pixel location Top: 104, Left: 259, Bottom: 211, Right: 366
# A face is located at pixel location Top: 116, Left: 275, Bottom: 206, Right: 364
# A face is located at pixel location Top: 116, Left: 275, Bottom: 206, Right: 364
# A face is located at pixel location Top: 126, Left: 275, Bottom: 216, Right: 364
# A face is located at pixel location Top: 126, Left: 275, Bottom: 216, Right: 364
# A face is located at pixel location Top: 116, Left: 270, Bottom: 223, Right: 378
# A face is located at pixel location Top: 116, Left: 270, Bottom: 223, Right: 378
# A face is located at pixel location Top: 126, Left: 285, Bottom: 216, Right: 374
# A face is located at pixel location Top: 126, Left: 285, Bottom: 216, Right: 374
# A face is located at pixel location Top: 126, Left: 285, Bottom: 216, Right: 374
# A face is located at pixel location Top: 126, Left: 285, Bottom: 216, Right: 374
# A face is located at pixel location Top: 116, Left: 282, Bottom: 223, Right: 390
# A face is located at pixel location Top: 126, Left: 295, Bottom: 216, Right: 384
# A face is located at pixel location Top: 126, Left: 295, Bottom: 216, Right: 384
# A face is located at pixel location Top: 116, Left: 282, Bottom: 223, Right: 390
# A face is located at pixel location Top: 136, Left: 295, Bottom: 226, Right: 384
# A face is located at pixel location Top: 136, Left: 295, Bottom: 226, Right: 384
# A face is located at pixel location Top: 136, Left: 295, Bottom: 226, Right: 384
# A face is located at pixel location Top: 128, Left: 294, Bottom: 235, Right: 402
# A face is located at pixel location Top: 136, Left: 295, Bottom: 226, Right: 384
# A face is located at pixel location Top: 136, Left: 305, Bottom: 226, Right: 394
# A face is located at pixel location Top: 136, Left: 305, Bottom: 226, Right: 394
# A face is located at pixel location Top: 136, Left: 315, Bottom: 226, Right: 404
# A face is located at pixel location Top: 146, Left: 325, Bottom: 236, Right: 414
# A face is located at pixel location Top: 130, Left: 370, Bottom: 204, Right: 444
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-1b2feb7df3d5> in <module>
#      23
#      24     ret, frame = video.read()
# ---> 25     frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#      26     if ret == False:
#      27         print("Frame doesn't Exist")
#
# error: OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
# !git init

# %%
import face_alignment
from skimage import io
import os

framepath = videoname+'_frame/frame '

fa = face_alignment.FaceAlignment(face_alignment.LandmarksType._3D, flip_input=False)

for i in range(len(os.walk(path).__next__()[2])):
    input = io.imread(framepath+str(i)+'.jpg')
    preds = fa.get_landmarks(input)

# %% [markdown]
# # 설치한 패키지들
#
# * conda install cmake
#
# * conda install pillow
#
# * conda install -c menpo dlib
#
# * pip install face_alignment
#
# * pip install opencv-python
#
# * pip install face_recognition
